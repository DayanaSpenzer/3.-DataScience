# %%
from Univariate import Univariate
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")

# %%
quan, qual = Univariate.QuanQual(dataset)

# %%
descriptive=pd.DataFrame(index=["mean","median","mode"],columns=quan)
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# median   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
for columnName in quan:
    descriptive[columnName]["mean"]=dataset[columnName].mean()
    descriptive[columnName]["median"]=dataset[columnName].median()
    descriptive[columnName]["mode"]=dataset[columnName].mode()[0]

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# median  108.0       67.0       65.0       66.0       71.0       62.0
# mode        1       62.0       63.0       65.0       60.0       56.7
#
#                salary
# mean    288655.405405
# median       265000.0
# mode         300000.0

# %%
descriptive=Univariate.UniVariate(dataset,quan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14040\3007608171.py in <module>
# ----> 1 descriptive=Univariate.UniVariate(dataset,quan)
#
# C:\HOPE AI Course\3. DataScience\2. Central Tendency\Univariate.py in UniVariate(dataset, quan)
#      11
#      12     def UniVariate(dataset,quan):
# ---> 13         descriptive=pd.DataFrame(index=["mean","median","mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%",
#      14                                "IQR","1.5rule","Lesser","Greater","Min","Max"],columns=quan)
#      15         for columnName in quan:
#
# NameError: name 'pd' is not defined
